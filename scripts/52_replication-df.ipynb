# %%
import json
import os
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats
from scipy.stats import kstest
import numpy as np
import networkx as nx
import pydot
from networkx.drawing.nx_pydot import graphviz_layout
import powerlaw
from statsmodels.api import qqplot
from datetime import datetime, timedelta

import utils.processing_utils as pu
import utils.simulation_utils as su

# %%
save_figs = False
start_str="reddit-sim_qwen_pf1-24h"

# %%
pu.batch_convert_db_contents(start_str=start_str)
# Out:
# Connecting to reddit-sim_qwen_pf1-24h
# Tables saved at /../abyss/home/oasis/oasis-rutschmanna/data/db_json/reddit-sim_qwen_pf1-24h/sp1/

# %% [markdown]
# ***
# # Load Sim Data

# %%
data = pu.load_db_json_data(
    "/../abyss/home/oasis/oasis-rutschmanna/data/db_json/",
    start_str,
    to_df=True
)

for i in list(data.keys()):
    data[i]["n_agents"] = data[i]["persona_file"].map(
        subreddit_personas
    ).apply(len)
# Out:
# Reading:  reddit-sim_qwen_pf1-24h

# %%
structure_data = {}
for i in list(data.keys()):
    vol, width, depth, scale, active, comment_lengths = pu.structure_analysis(
        data[i]
    )
    structure_data[i] = {
        "volume" : vol,
        "width" : width,
        "depth" : depth,
        "scale" : scale,
        "active" : active,
        "comment_lengths" : comment_lengths
    }

# %%
# structure_data

# %% [markdown]
# ***
# # Structural Analysis

# %%
# Print avg. share of actives in SIM
temp = [[], []]
for i in list(structure_data.keys()):
    temp[0].append(structure_data[i]["scale"])
    temp[1].append(structure_data[i]["active"])

print("# Users:", np.mean(temp[0]))
print("% Users:", np.mean(temp[1]))
# Out:
# # Users: 2.0
# % Users: 0.025

# %%
# Load User data and discussions data
seed_data = pd.read_csv("../../oswald-et-al_2025/pre_survey_anon.csv")
sample_data = pd.read_csv(
    "../../oswald-et-al_2025/sample_anon.csv"
)

seed_data.drop_duplicates("ParticipantID", inplace=True)
seed_data = seed_data.loc[seed_data["on_reddit"] == 1]
print(len(seed_data))

discussions_data = pd.read_csv(
    "../../oswald-et-al_2025/discussions_anon.csv",
    index_col=0
)
discussions_data.dropna(subset="ParticipantID", inplace=True)
print(len(discussions_data))

# Group by participant and count number of submissions created during experiment
discussions_data["comment_count"] = discussions_data.groupby(
    "ParticipantID"
)["ParticipantID"].transform("count").map(int)

discussions_data_merge = discussions_data[[
    "ParticipantID", "comment_count"
]].drop_duplicates()

seed_data = seed_data.merge(discussions_data_merge,
                            how="left",on="ParticipantID")

seed_data.fillna({"comment_count" : 0}, inplace=True)
# Print total user # and share of actives
print(len(seed_data))
print(len(seed_data[seed_data["comment_count"] != 0]) / len(seed_data))
# Out:
# 520
# 5792
# 520
# 0.6365384615384615

# %%
# Replace NAs with 0 for further analysis (0 comments, 0 likes, etc.)
sample_data = sample_data[[
    "ParticipantID",
    "subreddit",
    "polinterest",
    "time_online",
    "social_media",
    "comments_online",
    "comment_count",
    "comment_mean_lenght",
    "comment_mean_score",
    "comment_mean_tox"
]]

sample_data.rename(columns={"comment_mean_lenght":"comment_mean_length"},
                  inplace=True)

sample_data.fillna(0, inplace=True)
print(len(sample_data))

sample_sub_1_data = sample_data[sample_data["subreddit"] == "DiscussPolitics1"]
# Out:
# 520

# %%
def process_plot_data(data, metric, cummulate=True):
    if cummulate:
        return [i for j in [i[metric] for i in data.values()] for i in j]
    else:
        return [i[metric] for i in data.values()]

# %%
# Plot simulation descriptives
fig, axs = plt.subplots(1, 5, figsize=(15, 5))

axs[0].hist(process_plot_data(structure_data, "volume"))
axs[0].set_xlabel("volume")

axs[1].hist(process_plot_data(structure_data, "width"))
axs[1].set_xlabel("width")

axs[2].hist(process_plot_data(structure_data, "depth"))
axs[2].set_xlabel("depth")

axs[3].hist(process_plot_data(structure_data, "scale"))
axs[3].set_xlabel("scale")

axs[4].hist(process_plot_data(structure_data, "active"))
axs[4].set_xlabel("active")

if save_figs:
    plt.savefig("figures/sim_descriptives.jpg")
plt.show()

# %%
# Plot dist of volume across sim and seed threads
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].hist(process_plot_data(structure_data, "volume"))
axs[0].set_xlabel("Volume")

temp = discussions_data.groupby(["subreddit", "post_title"]).count()["comment_id"]

print(discussions_data.groupby([
    "subreddit", "post_title"
]).count()["ParticipantID"].sum())

axs[1].hist(temp, color="y", label="Seed")
axs[1].set_xlabel("Volume")

# plt.legend()
if save_figs:
    plt.savefig("figures/seed-sim_vol.jpg")
plt.show()
# Out:
# 5792

# %%
# Plot dist of scale across sim and seed threads
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].hist(process_plot_data(structure_data, "scale"), label="SIM")
axs[0].set_xlabel("Scale")

temp = discussions_data.groupby([
    "subreddit", "post_title"
]).nunique("ParticipantID")

axs[1].hist(temp["ParticipantID"], color="y", label="Seed")
axs[1].set_xlabel("Scale")

# plt.legend()
if save_figs:
    plt.savefig("figures/seed-sim_dist_scale.jpg")
plt.show()

# %%
# Plot dist of comment lengths for all Sims
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].hist([i for j in process_plot_data(
    structure_data, "comment_lengths"
) for i in j],
           label="Sim")

axs[0].set_xlabel("Comment Length")

axs[1].hist(
    discussions_data["length_comment_char"], color="y", bins=100, label="Seed"
)
axs[1].set_xlabel("Comment Length")
axs[1].set_xlim(0, 1050)

# plt.legend()
if save_figs:
    plt.savefig("figures/seed-sim_dist_comment-lengths.jpg")
plt.show()

# %%
# Plot dist of comment lengths for all Sims
fig, axs = plt.subplots(2, 3, figsize=(10, 8))

for i in range(2):
    for j in range(3):
        temp = discussions_data.loc[discussions_data["subreddit"] == f"DiscussPolitics{(i+1)*(j+1)}"]
        axs[i][j].hist(
            temp["length_comment_char"], color="y", label="Seed"
        )
        axs[i][j].set_xlabel("Comment Length")
        axs[i][j].set_xlim(0, 2000)

# plt.legend()
if save_figs:
    plt.savefig("figures/seed_dist_sub-comment-lengths.jpg")
plt.show()

# %%
# Visualize the thread structure in tree form
for i in range(1, 2):
    thread_tree = []
    node_labels = {}
    
    temp = list(data.values())[0]
    temp = temp[temp["post_id"] == i]
    
    for j, r in temp.iterrows():
        if r["parent_comment_id"] == -1:
            thread_tree.append((0, r["comment_id"]))
        else:
            thread_tree.append((r["parent_comment_id"], r["comment_id"]))
        node_labels[r["comment_id"]] = r["user_id"]
    
    G = nx.Graph()
    G.add_edges_from(thread_tree)
    pos = graphviz_layout(G, prog="dot")
    
    fig, axs = plt.subplots(1, 1, figsize=(40, 10))
    nx.draw(
        G, pos, with_labels=True, labels=node_labels, node_size=300,
        node_color='lightblue', font_weight='bold', font_size=8
    )
    if save_figs:
        plt.savefig("figures/sim_thread-tree.jpg")
    plt.show()

# %%
# temp = discussions_data.groupby(["ParticipantID", "post_title"]).size().groupby("ParticipantID").idxmax().apply(pd.Series)[1]

# for i, r in temp.items():
#     comments = discussions_data[
#     discussions_data["ParticipantID"] == i
#     ]
#     comments = comments[comments["post_title"] == r][
#     "created_comment"
#     ]
    
#     fig, ax = plt.subplots(figsize=(12, 2))
    
#     # Plot vertical lines at each comment time
#     for comment in pd.to_datetime(comments):
#         ax.axvline(x=comment, color='b', linestyle='--', alpha=0.7)
    
#     # Set the title and labels
#     ax.set_xlim([pd.to_datetime(comments).min() - pd.Timedelta(minutes=1),
#                  pd.to_datetime(comments).max() + pd.Timedelta(minutes=1)])
#     ax.set_ylim([0, 0.1])
#     ax.set_title(f"Comment Times for Participant {i}\n{r}")
#     ax.set_xlabel("Time")
    
#     # Rotate x-axis labels for better readability
#     plt.xticks(rotation=45)    
#     plt.yticks([])
    
#     # Show the plot
#     plt.tight_layout()
#     plt.show()

# %%
# Seed
temp = discussions_data.groupby(["ParticipantID", "post_title"]).size().sort_values().tail(5)

j = 0
fig, axs = plt.subplots(5, 1, figsize=(12, 10))
for i, r in temp.items():
    comments = discussions_data[
    discussions_data["ParticipantID"] == i[0]
    ]
    comments = comments[comments["post_title"] == i[1]][
    "created_comment"
    ]
    
    for comment in pd.to_datetime(comments):
        axs[j].axvline(x=comment, color='b', linestyle='--', alpha=0.7)
    
    # axs[j].set_xlim([pd.to_datetime(comments).min() - pd.Timedelta(minutes=1),
    #              pd.to_datetime(comments).max() + pd.Timedelta(minutes=1)])
    axs[j].set_xlim([pd.to_datetime(comments).min() - pd.Timedelta(minutes=1),
                 pd.to_datetime(comments).min() + pd.Timedelta(hours=24, minutes=1)])
    axs[j].set_ylim([0, 0.1])
    axs[j].set_title(f"Comment Times for Seed Agent {i[0]}\n{i[1]}")
    axs[j].set_xlabel("Publication Time")

    axs[j].set_yticks([])

    j += 1

plt.tight_layout()
if save_figs:
    plt.savefig("figures/seed_top-5_burst.jpg")
plt.show()

# %%
# SIM
n = 5
t = data[list(data.keys())[0]]
# t = t[t["seed_post"] == 14]
temp = t.groupby(["user_id", "seed_post"]).size().sort_values().tail(n)

j = 0
fig, axs = plt.subplots(n, 1, figsize=(12, n*2))
for i, r in temp.items():
    comments = t[
    t["user_id"] == i[0]
    ]
    comments = comments[comments["seed_post"] == i[1]][
    "created_at"
    ]
    
    for comment in pd.to_datetime(comments):
        axs[j].axvline(x=comment, color='b', linestyle='--', alpha=0.7)
    
    # axs[j].set_xlim([pd.to_datetime(comments).min() - pd.Timedelta(minutes=1),
    #              pd.to_datetime(comments).max() + pd.Timedelta(minutes=1)])
    axs[j].set_xlim([pd.to_datetime(comments).min() - pd.Timedelta(minutes=1),
                 pd.to_datetime(comments).min() + pd.Timedelta(hours=24, minutes=1)])
    axs[j].set_ylim([0, 0.1])
    axs[j].set_title(f"Comment Times for Agent {i[0]}\n{i[1]}")
    axs[j].set_xlabel("Publication Time")

    axs[j].set_yticks([])

    j += 1

plt.tight_layout()
if save_figs:
    plt.savefig("figures/sim_top-5_burst.jpg")
plt.show()

# %%
# Determine intial activation prob
k = 0
n = 72
ps = [0.0005, 0.00075, 0.003, 0.01, 0.025]

for p in ps:
    print(f"Min. {k+1} over {n}({p})", scipy.stats.binom.sf(k, n, p))
# Out:
# Min. 1 over 72(0.0005) 0.035368391135430985
# Min. 1 over 72(0.00075) 0.05258708840206131
# Min. 1 over 72(0.003) 0.19452623720183446
# Min. 1 over 72(0.01) 0.5150086297258368
# Min. 1 over 72(0.025) 0.8384405632911972

# %%
# Visualize custom activation function (visualize with sim data!)
# temp = []
# for i in range(1000):
#     temp.append(len(su.activation_function(seed_data.set_index("ParticipantID"),
#                                            "/../abyss/home/oasis/oasis-rutschmanna/data/dbs/reddit-sim_dp1_qwen-18h_12-27.db",
#                                            print_info=False)))

# plt.hist(temp)
# plt.show()

# %%
def get_quartiles(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    lb = q1 - 1.5*iqr
    ub = q3 + 1.5*iqr
    return lb, ub

# Visualize Seed activation probability function
discussions_data["created_comment"] = pd.to_datetime(
    discussions_data["created_comment"]
)
discussions_data["interevent_diff"] = discussions_data.sort_values(
["ParticipantID", "created_comment"]
).groupby("ParticipantID")["created_comment"].diff().dt.total_seconds()

# Get most active seed user
# discussions_data.groupby("ParticipantID").size().sort_values()

temp = discussions_data.copy()

print(temp["interevent_diff"].isna().sum())
temp.dropna(subset=["interevent_diff"], inplace=True)
temp = temp[temp["interevent_diff"] != 0.0]
# remove outliers
temp = temp[temp["interevent_diff"] <= get_quartiles(
    temp["interevent_diff"]
)[1]]
temp = temp["interevent_diff"].sort_values()
print(len(temp))
# Out:
# 334
# 4863

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 8))

qqplot(temp, scipy.stats.distributions.powerlaw, line="45", fit=True, ax=ax[0])
ax[0].set_title("Powerlaw")

qqplot(np.log(temp), scipy.stats.distributions.lognorm, line="45", fit=True, ax=ax[1])
ax[1].set_title("Lognorm")

qqplot(temp, scipy.stats.distributions.expon, line="45", fit=True, ax=ax[2])
ax[2].set_title("Exponential")

if save_figs:
    plt.savefig("figures/seed_inter-event-qqplots.jpg")
plt.show()

# %%
# Perform Kolmogorov-Smirnov test
fit = powerlaw.Fit(xmin=temp.min(), xmax=temp.max(), data=temp)

for i, j in zip([fit.power_law.cdf, fit.lognormal.cdf, fit.exponential.cdf], ["powerlaw", "lognormal", "expon"]):
    ks_statistic, p_value = kstest(temp, i)

    print(f"{j} KS Statistic: {ks_statistic}")
    print(f"{j} P-value: {p_value}")
# Out:
# powerlaw KS Statistic: 0.35304341241737014
# powerlaw P-value: 0.0
# lognormal KS Statistic: 0.21227751112169246
# lognormal P-value: 9.033628107175204e-193
# expon KS Statistic: 0.3829401931052466
# expon P-value: 0.0

# %%
fig, axs = plt.subplots(1, 3, figsize=(14, 8))

fit.plot_pdf(ax=axs[0])
fit.power_law.plot_pdf(color="r", ax=axs[0])
fit.lognormal.plot_pdf(color="g", ax=axs[0])
fit.exponential.plot_pdf(color="y", ax=axs[0])

fit.plot_cdf(ax=axs[1])
fit.power_law.plot_cdf(color="r", ax=axs[1])
fit.lognormal.plot_cdf(color="g", ax=axs[1])
fit.exponential.plot_cdf(color="y", ax=axs[1])

fit.plot_ccdf(ax=axs[2], label="Data")
fit.power_law.plot_ccdf(color="r", ax=axs[2], label="Powerlaw")
fit.lognormal.plot_ccdf(color="g", ax=axs[2], label="Lognormal")
fit.exponential.plot_ccdf(color="y", ax=axs[2], label="Exponential")

axs[0].set_ylabel("Density")
axs[0].set_title("PDF")

axs[1].set_xlabel("Inter-Event Time")
axs[1].set_title("CDF")

axs[2].set_title("CCDF")

plt.legend()
if save_figs:
    plt.savefig("figures/seed_inter-event-pdf.jpg")
plt.show()

# %%
mu = fit.lognormal.mu
sigma = fit.lognormal.sigma

print(f"Estimated mu: {mu}")
print(f"Estimated sigma: {sigma}")
# Out:
# Estimated mu: 8.465372775046776
# Estimated sigma: 2.7585282466115832

# %%
# Compare power law with exponential distribution
R, p = fit.distribution_compare('power_law', 'exponential')
print(f"power-law vs. exponential: R = {R}, p = {p}")

# Compare power law with log-normal distribution
R, p = fit.distribution_compare('power_law', 'lognormal')
print(f"power-law vs. log-normal: R = {R}, p = {p}")
# Out:
# power-law vs. exponential: R = 948.2483842447346, p = 2.042828217581967e-10
# power-law vs. log-normal: R = -2308.4225867202226, p = 0.0

# %%
# Lognormal dist fits data best ()
x = 20800
cdf_value = round(scipy.stats.lognorm.sf(x, s=fit.lognormal.sigma, scale=np.exp(fit.lognormal.mu)), 3)
print(f"P(i) at {round(x/60/60, 2)}h ({x}s) is {cdf_value}")
# Out:
# P(i) at 5.78h (20800s) is 0.296

# %%
fig, axs = plt.subplots(1, 1, figsize=(10, 8))

axs.hist(temp, density=True)
# axs.hist(temp, density=True, bins=5468)

axs.set_xlabel("Inter-Event Time")
# axs.set_xlim(0, 10000)
axs.set_ylabel("Density")

plt.show()

# %% [markdown]
# ***
# # Merge Sim and Seed Agent Data

# %%
# Merge LLM Agents with their respective Seed Users
seed_sub_1_data = seed_data[seed_data["subreddit"] == "DiscussPolitics1"]

seed_sub_1_data = seed_sub_1_data[[
    "ParticipantID",
    "polinterest",
    "time_online",
    "social_media",
    "comments_online",
    "comment_count",
]]

print(len(seed_sub_1_data))
# Out:
# 80

# %%
for k in list(data.keys()):
    llm_posts = {}
    for i in seed_sub_1_data["ParticipantID"]:
        user_posts = []
        for j in data[k]:
            if i == j["seed_user_id"]:
                user_posts.append(j)
    
        llm_posts[i] = user_posts

    seed_sub_1_data[k] = seed_sub_1_data["ParticipantID"].map(llm_posts)
    seed_sub_1_data[f"{k}_comment_count"] = seed_sub_1_data[k].map(len)

# %% [markdown]
# ***
# # Interaction Analysis

# %%
discussions_data["created_comment"] = pd.to_datetime(
    discussions_data["created_comment"]
)
discussions_data.groupby(["subreddit", "post_title"])["created_comment"].transform(
    lambda x: x.max() - x.min()
).median()
# Out:
# Timedelta('5 days 17:47:37')

# %%
# Correlation between self-reported vars and comment # for llm agents
for i in list(seed_sub_1_data.filter(regex="_comment_count").columns):
    for j in ["polinterest", "time_online", "social_media", "comments_online"]:
        corr = scipy.stats.spearmanr(seed_sub_1_data[j],
                                    seed_sub_1_data[i])
        if corr.pvalue <= 0.05:
            print(i, j, corr)
# Out:
# reddit-sim_dp1_qwen-18h_14-55_comment_count comments_online SignificanceResult(statistic=np.float64(0.5254753354500111), pvalue=np.float64(5.592427663749464e-07))
# reddit-sim_dp1_qwen-18h_18-58_comment_count time_online SignificanceResult(statistic=np.float64(0.22406890570218327), pvalue=np.float64(0.04570856574236898))
# reddit-sim_dp1_qwen-18h_18-58_comment_count comments_online SignificanceResult(statistic=np.float64(0.5123293901155671), pvalue=np.float64(1.185685693461269e-06))
# reddit-sim_dp1_qwen-18h_15-30_comment_count social_media SignificanceResult(statistic=np.float64(0.2573823299058723), pvalue=np.float64(0.021175341772909858))
# reddit-sim_dp1_qwen-18h_15-30_comment_count comments_online SignificanceResult(statistic=np.float64(0.5201008373589349), pvalue=np.float64(7.632883187701883e-07))
# reddit-sim_dp1_qwen-18h_16-49_comment_count social_media SignificanceResult(statistic=np.float64(0.27183351331469097), pvalue=np.float64(0.014719507243276175))
# reddit-sim_dp1_qwen-18h_16-49_comment_count comments_online SignificanceResult(statistic=np.float64(0.6056881445623393), pvalue=np.float64(2.6416186728666865e-09))
# reddit-sim_dp1_qwen-18h_13-44_comment_count social_media SignificanceResult(statistic=np.float64(0.23718566305574212), pvalue=np.float64(0.03414168845443311))
# reddit-sim_dp1_qwen-18h_13-44_comment_count comments_online SignificanceResult(statistic=np.float64(0.5720661355725419), pvalue=np.float64(2.9687275085627558e-08))
# reddit-sim_dp1_qwen-18h_17-30_comment_count comments_online SignificanceResult(statistic=np.float64(0.5102660714297887), pvalue=np.float64(1.3303455708452247e-06))
# reddit-sim_dp1_qwen-18h_12-27_comment_count comments_online SignificanceResult(statistic=np.float64(0.24134978565548026), pvalue=np.float64(0.031027874943475323))
# reddit-sim_dp1_qwen-18h_14-12_comment_count time_online SignificanceResult(statistic=np.float64(0.33562573771204607), pvalue=np.float64(0.002338561654988531))
# reddit-sim_dp1_qwen-18h_14-12_comment_count social_media SignificanceResult(statistic=np.float64(0.2804386565363913), pvalue=np.float64(0.011748079499142092))
# reddit-sim_dp1_qwen-18h_14-12_comment_count comments_online SignificanceResult(statistic=np.float64(0.476598719904635), pvalue=np.float64(7.85738144366495e-06))
# reddit-sim_dp1_qwen-18h_14-39_comment_count comments_online SignificanceResult(statistic=np.float64(0.6050619678302807), pvalue=np.float64(2.7705170967825586e-09))
# reddit-sim_dp1_qwen-18h_13-21_comment_count comments_online SignificanceResult(statistic=np.float64(0.5116464843742659), pvalue=np.float64(1.231836122968688e-06))
# reddit-sim_dp1_qwen-18h_13-59_comment_count time_online SignificanceResult(statistic=np.float64(0.25698436162267346), pvalue=np.float64(0.021382878247625338))
# reddit-sim_dp1_qwen-18h_13-59_comment_count comments_online SignificanceResult(statistic=np.float64(0.4438577500373298), pvalue=np.float64(3.7245427769502797e-05))
# reddit-sim_dp1_qwen-18h_16-19_comment_count comments_online SignificanceResult(statistic=np.float64(0.35946100091375954), pvalue=np.float64(0.0010577276308291008))
# reddit-sim_dp1_qwen-18h_18-41_comment_count time_online SignificanceResult(statistic=np.float64(0.3354208342647641), pvalue=np.float64(0.002353947877640829))
# reddit-sim_dp1_qwen-18h_18-41_comment_count comments_online SignificanceResult(statistic=np.float64(0.4461264873192996), pvalue=np.float64(3.360805376000584e-05))
# reddit-sim_dp1_qwen-18h_15-53_comment_count polinterest SignificanceResult(statistic=np.float64(0.25116641149907193), pvalue=np.float64(0.02462087084183114))
# reddit-sim_dp1_qwen-18h_15-53_comment_count comments_online SignificanceResult(statistic=np.float64(0.4824724292203933), pvalue=np.float64(5.841651647323755e-06))
# reddit-sim_dp1_qwen-18h_18-06_comment_count social_media SignificanceResult(statistic=np.float64(0.2352848948480218), pvalue=np.float64(0.03564777516319758))
# reddit-sim_dp1_qwen-18h_18-06_comment_count comments_online SignificanceResult(statistic=np.float64(0.4704744540914441), pvalue=np.float64(1.0641645999990243e-05))
# reddit-sim_dp1_qwen-18h_15-20_comment_count comments_online SignificanceResult(statistic=np.float64(0.3221974336419564), pvalue=np.float64(0.003561238800306937))
# reddit-sim_dp1_qwen-18h_17-07_comment_count time_online SignificanceResult(statistic=np.float64(0.22043026718468542), pvalue=np.float64(0.04943758412556597))
# reddit-sim_dp1_qwen-18h_17-07_comment_count comments_online SignificanceResult(statistic=np.float64(0.5442092822436818), pvalue=np.float64(1.8115435834965542e-07))
# reddit-sim_dp1_qwen-18h_12-58_comment_count polinterest SignificanceResult(statistic=np.float64(-0.22975621116720887), pvalue=np.float64(0.040347536215836206))
# reddit-sim_dp1_qwen-18h_12-58_comment_count comments_online SignificanceResult(statistic=np.float64(0.36790483201638435), pvalue=np.float64(0.0007867079528991803))
# reddit-sim_dp1_qwen-18h_18-20_comment_count comments_online SignificanceResult(statistic=np.float64(0.3639027475951897), pvalue=np.float64(0.0009061087636980688))
# reddit-sim_dp1_qwen-18h_14-25_comment_count comments_online SignificanceResult(statistic=np.float64(0.31120008442991837), pvalue=np.float64(0.0049575111647277405))

# %%
temp = {"stat" : [], "p" : []}
for i in list(seed_sub_1_data.filter(regex="_comment_count").columns):
    corr = scipy.stats.spearmanr(seed_sub_1_data["polinterest"],
                                seed_sub_1_data[i])
    temp["stat"].append(corr.statistic)
    temp["p"].append(corr.pvalue)

print("polinterest", pu.fisher(temp))
# Out:
# polinterest (np.float64(0.019995453092000667), np.float64(0.4574579946696036))

# %%
temp = {"stat" : [], "p" : []}
for i in list(seed_sub_1_data.filter(regex="_comment_count").columns):
    corr = scipy.stats.spearmanr(seed_sub_1_data["time_online"],
                                seed_sub_1_data[i])
    temp["stat"].append(corr.statistic)
    temp["p"].append(corr.pvalue)

print("time_online", pu.fisher(temp))
# Out:
# time_online (np.float64(0.17170043282884498), np.float64(3.2848602026236406e-06))

# %%
temp = {"stat" : [], "p" : []}
for i in list(seed_sub_1_data.filter(regex="_comment_count").columns):
    corr = scipy.stats.spearmanr(seed_sub_1_data["social_media"],
                                seed_sub_1_data[i])
    temp["stat"].append(corr.statistic)
    temp["p"].append(corr.pvalue)

print("social_media", pu.fisher(temp))
# Out:
# social_media (np.float64(0.14373094866081754), np.float64(0.0006696141321896887))

# %%
temp = {"stat" : [], "p" : []}
for i in list(seed_sub_1_data.filter(regex="_comment_count").columns):
    corr = scipy.stats.spearmanr(seed_sub_1_data["comments_online"],
                                seed_sub_1_data[i])
    temp["stat"].append(corr.statistic)
    temp["p"].append(corr.pvalue)

print("comments_online", pu.fisher(temp))
# Out:
# comments_online (np.float64(0.45961946868816), np.float64(0.0))

# %%
# Comparison of self-reported vars in whole sample vs. Sub 1
plt.rcParams['axes.prop_cycle'] = plt.cycler(color="y")
fig, axs = plt.subplots(2, 4, figsize=(14, 5))

axs[0,0].hist(seed_data["polinterest"])
axs[0,0].set_ylabel("All User Data")

axs[0,1].hist(seed_data["time_online"])

axs[0,2].hist(seed_data["social_media"])

axs[0,3].hist(seed_data["comments_online"])

axs[1,0].hist(seed_sub_1_data["polinterest"])
axs[1,0].set_xlabel("polinterest")
axs[1,0].set_ylabel("Sub 1 User Data")

axs[1,1].hist(seed_sub_1_data["time_online"])
axs[1,1].set_xlabel("time_online")

axs[1,2].hist(seed_sub_1_data["social_media"])
axs[1,2].set_xlabel("social_media")

axs[1,3].hist(seed_sub_1_data["comments_online"])
axs[1,3].set_xlabel("comments_online")

if save_figs:
    plt.savefig("figures/whole-sub1_self-reports.jpg")
plt.show()

# %%
# Whole sample correlation analysis
scipy.stats.spearmanr(seed_data["polinterest"], 
                      seed_data["comment_count"])
# Out:
# SignificanceResult(statistic=np.float64(0.07959907085369836), pvalue=np.float64(0.0697318497152728))

# %%
# Whole sample correlation analysis
scipy.stats.spearmanr(seed_data["time_online"],
                      seed_data["comment_count"])
# Out:
# SignificanceResult(statistic=np.float64(-0.06097692149655422), pvalue=np.float64(0.1650050053764535))

# %%
# Whole sample correlation analysis
scipy.stats.spearmanr(seed_data["social_media"],
                      seed_data["comment_count"])
# Out:
# SignificanceResult(statistic=np.float64(0.04920081140413537), pvalue=np.float64(0.2627438135586968))

# %%
# Whole sample correlation analysis
scipy.stats.spearmanr(seed_data["comments_online"],
                      seed_data["comment_count"])
# Out:
# SignificanceResult(statistic=np.float64(0.13399045580204383), pvalue=np.float64(0.0021992413183149007))

# %% [markdown]
# ***
# # Content Analysis

# %%
with open("perspective_secret.txt", "r") as f:
    api_key = f.read()

# %%
# j = pu.query_perspective(data[list(data.keys())[0]], api_key)

# with open("perspective_rating.json", "w") as f:
#     json.dump(j, f, indent=4)

# %%
with open("perspective_rating.json", "r") as f:
    responses = json.load(f)

# %% [markdown]
# ***
# # Junk yard

# %%
st = datetime(2025, 6, 4, 13, 00, 00)

class Clock:
    r"""Clock used for the sandbox."""

    def __init__(self, k: int = 1):
        self.real_start_time = st
        self.k = k
        self.time_step = 0

    def time_transfer(self, now_time: datetime,
                      start_time: datetime) -> datetime:
        time_diff = now_time - self.real_start_time
        adjusted_diff = self.k * time_diff
        adjusted_time = start_time + adjusted_diff
        return adjusted_time

    def get_time_step(self) -> str:
        return str(self.time_step)

class Env:
    def __init__(self):
        self.start_time = st
        self.sandbox_clock = Clock(60)

# %%
env = Env()

# %%
import sqlite3
import pandas as pd
import random
from datetime import datetime, timedelta

def activation_function(
    data,
    db_path,
    env,
    mapping_type="comments",
    print_info=True,
    initiation_ie_time=3600,
    inter_burst_time=3600*3,
    distribution_type="lognorm",
    sigma=2.759,
    mu=8.465,
    recurring_activation_prob_modifier=0.1
):
    """
    Determines the activation of LLM agents in the OASIS simulation.
    Each agent is assigned a probability of activation depending
    on the seed user's self reported online behavior.

    Parameters
    data: seed user data (contains self-reported online behavior)
        indexed by ParticipantID (seed_id)
    db_path: path to OASIS simulation data base
    """

    current_time = env.sandbox_clock.time_transfer(
                datetime.now(), env.start_time)
    
    if mapping_type == "comments":
        mapping = {
            1: 0.005,  # never
            2: 0.0075, # once per month
            3: 0.03,   # once per week
            4: 0.05,   # almost daily
            5: 0.1,    # multiple times a day
        }
    elif mapping_type == "social_media": # very high!
        mapping = {
            1: 0.01, # not at all
            2: 0.03, # a couple of times per week
            3: 0.08, # about once per day
            4: 0.12, # multiple times per day
            5: 0.15, # almost constantly
        }
    
    # Create empty list to hold IDs of activated agents
    activated_agents_step = []

    # Access content from "live" db
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # User data
    cursor.execute("SELECT user_id, user_name FROM user")

    rows = cursor.fetchall()
    columns = [col[0] for col in cursor.description]
    db_content = [dict(zip(columns, row)) for row in rows]

    # Comment data
    cursor.execute("SELECT user_id, created_at FROM comment")

    rows = cursor.fetchall()
    columns = [col[0] for col in cursor.description]
    previous_activations = [dict(zip(columns, row)) for row in rows]
    
    conn.close()

    activated_agents = {}

    for i in previous_activations:
        timestamp_str = i["created_at"]
        timestamp = datetime.fromisoformat(timestamp_str)
        if i["user_id"] not in activated_agents.keys():
            activated_agents[i["user_id"]] = [timestamp]
        else:
            activated_agents[i["user_id"]].append(timestamp)
    
    # Decide agent activation
    for i in db_content:
        i["comments_online"] = data.at[i["user_name"], "comments_online"]
        i["activation_prob"] = mapping[i["comments_online"]]
        try:
            last_initiation = activated_agents[i["user_id"]][-1]
            # print(activated_agents[i["user_id"]][::-1])
            for j in activated_agents[i["user_id"]][::-1]:
                # print("Diff:", last_initiation - j)
                if last_initiation - j <= timedelta(seconds=initiation_ie_time):
                    last_initiation = j
                else:
                    break
            i["last_initiation"] = last_initiation
        except:
            i["last_initiation"] = datetime(1970, 1, 1, 0, 0, 0)

        activation_threshold = random.random()
        if i["user_id"] not in activated_agents:
            activation_prob = i["activation_prob"] 
            i["activated"] = (
                True if activation_threshold < activation_prob else False
            )
        
        else:
            # Estimated mu: 8.465372775046776
            # Estimated sigma: 2.7585282466115832
            x = (current_time - i["last_initiation"]).total_seconds()
            recurring_activation_prob = round(
                scipy.stats.lognorm.sf(x, s=sigma, scale=np.exp(mu)),
                3
            ) * recurring_activation_prob_modifier
            activation_prob = i["activation_prob"] + recurring_activation_prob
            # print(i["activation_prob"], x, recurring_activation_prob, activation_prob)
            i["activated"] = (
                True if activation_threshold < activation_prob else False
            )
        
        if i["activated"] == True:
            activated_agents_step.append(i["user_id"])

    if print_info:
        print("#" * 20)      
        print("Activation function activated:", len(activated_agents_step), "users.")
        print("#" * 20)
    return activated_agents_step

# %%
activation_function(
    sample_data.set_index("ParticipantID"), 
    "../data/test_dbs/all_subs/reddit-sim_dp1_qwen-24h_00-03.db",
    env,
    recurring_activation_prob_modifier=0.2
)
# Out:
# ####################
# Activation function activated: 3 users.
# ####################
# [39, 60, 70]

# %%
# Implement interaction burst dynamics
import sqlite3

db_path = "../data/test_dbs/all_subs/reddit-sim_dp1_qwen-24h_00-03.db"
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("SELECT user_id, created_at FROM trace")

rows = cursor.fetchall()
columns = [col[0] for col in cursor.description]
comment_content = [dict(zip(columns, row)) for row in rows]

conn.close()

comment_content
# Out:
# [{'user_id': 0, 'created_at': '2025-06-04 00:05:55.496093'},
#  {'user_id': 1, 'created_at': '2025-06-04 00:06:01.032413'},
#  {'user_id': 2, 'created_at': '2025-06-04 00:06:04.982693'},
#  {'user_id': 3, 'created_at': '2025-06-04 00:06:08.511293'},
#  {'user_id': 4, 'created_at': '2025-06-04 00:06:12.032273'},
#  {'user_id': 5, 'created_at': '2025-06-04 00:06:15.160973'},
#  {'user_id': 6, 'created_at': '2025-06-04 00:06:21.287513'},
#  {'user_id': 7, 'created_at': '2025-06-04 00:06:24.280913'},
#  {'user_id': 8, 'created_at': '2025-06-04 00:06:29.055173'},
#  {'user_id': 9, 'created_at': '2025-06-04 00:06:36.221873'},
#  {'user_id': 10, 'created_at': '2025-06-04 00:06:39.944753'},
#  {'user_id': 11, 'created_at': '2025-06-04 00:06:44.475353'},
#  {'user_id': 12, 'created_at': '2025-06-04 00:06:48.860393'},
#  {'user_id': 13, 'created_at': '2025-06-04 00:06:53.326613'},
#  {'user_id': 14, 'created_at': '2025-06-04 00:06:56.597393'},
#  {'user_id': 15, 'created_at': '2025-06-04 00:07:00.045713'},
#  {'user_id': 16, 'created_at': '2025-06-04 00:07:03.042893'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:07:07.293713'},
#  {'user_id': 18, 'created_at': '2025-06-04 00:07:12.370373'},
#  {'user_id': 19, 'created_at': '2025-06-04 00:07:16.109333'},
#  {'user_id': 20, 'created_at': '2025-06-04 00:07:19.817273'},
#  {'user_id': 21, 'created_at': '2025-06-04 00:07:23.146553'},
#  {'user_id': 22, 'created_at': '2025-06-04 00:07:26.681873'},
#  {'user_id': 23, 'created_at': '2025-06-04 00:07:31.430213'},
#  {'user_id': 24, 'created_at': '2025-06-04 00:07:37.653113'},
#  {'user_id': 25, 'created_at': '2025-06-04 00:07:40.926533'},
#  {'user_id': 26, 'created_at': '2025-06-04 00:07:44.584973'},
#  {'user_id': 27, 'created_at': '2025-06-04 00:07:49.139873'},
#  {'user_id': 28, 'created_at': '2025-06-04 00:07:52.435673'},
#  {'user_id': 29, 'created_at': '2025-06-04 00:07:55.840793'},
#  {'user_id': 30, 'created_at': '2025-06-04 00:07:59.231753'},
#  {'user_id': 31, 'created_at': '2025-06-04 00:08:03.581513'},
#  {'user_id': 32, 'created_at': '2025-06-04 00:08:07.919693'},
#  {'user_id': 33, 'created_at': '2025-06-04 00:08:11.467553'},
#  {'user_id': 34, 'created_at': '2025-06-04 00:08:14.739953'},
#  {'user_id': 35, 'created_at': '2025-06-04 00:08:18.407033'},
#  {'user_id': 36, 'created_at': '2025-06-04 00:08:21.908993'},
#  {'user_id': 37, 'created_at': '2025-06-04 00:08:25.738853'},
#  {'user_id': 38, 'created_at': '2025-06-04 00:08:29.386073'},
#  {'user_id': 39, 'created_at': '2025-06-04 00:08:33.056453'},
#  {'user_id': 40, 'created_at': '2025-06-04 00:08:36.160613'},
#  {'user_id': 41, 'created_at': '2025-06-04 00:08:42.403193'},
#  {'user_id': 42, 'created_at': '2025-06-04 00:08:46.686653'},
#  {'user_id': 43, 'created_at': '2025-06-04 00:08:51.406793'},
#  {'user_id': 44, 'created_at': '2025-06-04 00:08:55.379153'},
#  {'user_id': 45, 'created_at': '2025-06-04 00:08:59.528393'},
#  {'user_id': 46, 'created_at': '2025-06-04 00:09:04.807313'},
#  {'user_id': 47, 'created_at': '2025-06-04 00:09:08.693273'},
#  {'user_id': 48, 'created_at': '2025-06-04 00:09:16.876373'},
#  {'user_id': 49, 'created_at': '2025-06-04 00:09:21.026393'},
#  {'user_id': 50, 'created_at': '2025-06-04 00:09:24.515693'},
#  {'user_id': 51, 'created_at': '2025-06-04 00:09:27.770813'},
#  {'user_id': 52, 'created_at': '2025-06-04 00:09:31.469513'},
#  {'user_id': 53, 'created_at': '2025-06-04 00:09:35.394773'},
#  {'user_id': 54, 'created_at': '2025-06-04 00:09:39.645113'},
#  {'user_id': 55, 'created_at': '2025-06-04 00:09:42.843533'},
#  {'user_id': 56, 'created_at': '2025-06-04 00:09:46.377653'},
#  {'user_id': 57, 'created_at': '2025-06-04 00:09:50.696933'},
#  {'user_id': 58, 'created_at': '2025-06-04 00:09:54.554993'},
#  {'user_id': 59, 'created_at': '2025-06-04 00:09:58.217513'},
#  {'user_id': 60, 'created_at': '2025-06-04 00:10:02.304773'},
#  {'user_id': 61, 'created_at': '2025-06-04 00:10:05.832173'},
#  {'user_id': 62, 'created_at': '2025-06-04 00:10:09.803153'},
#  {'user_id': 63, 'created_at': '2025-06-04 00:10:14.253113'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:10:18.548153'},
#  {'user_id': 65, 'created_at': '2025-06-04 00:10:21.988193'},
#  {'user_id': 66, 'created_at': '2025-06-04 00:10:25.460933'},
#  {'user_id': 67, 'created_at': '2025-06-04 00:10:29.485373'},
#  {'user_id': 68, 'created_at': '2025-06-04 00:10:33.624713'},
#  {'user_id': 69, 'created_at': '2025-06-04 00:10:37.766813'},
#  {'user_id': 70, 'created_at': '2025-06-04 00:10:43.988633'},
#  {'user_id': 71, 'created_at': '2025-06-04 00:10:47.605193'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:10:51.497213'},
#  {'user_id': 73, 'created_at': '2025-06-04 00:10:55.005833'},
#  {'user_id': 74, 'created_at': '2025-06-04 00:10:58.558193'},
#  {'user_id': 75, 'created_at': '2025-06-04 00:11:02.295773'},
#  {'user_id': 76, 'created_at': '2025-06-04 00:11:06.642053'},
#  {'user_id': 77, 'created_at': '2025-06-04 00:11:10.060253'},
#  {'user_id': 78, 'created_at': '2025-06-04 00:11:13.426313'},
#  {'user_id': 79, 'created_at': '2025-06-04 00:11:17.633933'},
#  {'user_id': 0, 'created_at': '2025-06-04 00:11:23.053973'},
#  {'user_id': 9, 'created_at': '2025-06-04 00:11:32.082653'},
#  {'user_id': 66, 'created_at': '2025-06-04 00:11:34.717073'},
#  {'user_id': 9, 'created_at': '2025-06-04 00:20:24.612173'},
#  {'user_id': 9, 'created_at': '2025-06-04 00:20:28.635173'},
#  {'user_id': 66, 'created_at': '2025-06-04 00:31:57.947993'},
#  {'user_id': 58, 'created_at': '2025-06-04 00:32:07.004573'},
#  {'user_id': 33, 'created_at': '2025-06-04 00:32:09.109193'},
#  {'user_id': 51, 'created_at': '2025-06-04 00:32:10.979693'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:32:14.567693'},
#  {'user_id': 53, 'created_at': '2025-06-04 00:32:16.856693'},
#  {'user_id': 16, 'created_at': '2025-06-04 00:32:20.158193'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:32:23.412233'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:32:26.302913'},
#  {'user_id': 41, 'created_at': '2025-06-04 00:32:29.390693'},
#  {'user_id': 79, 'created_at': '2025-06-04 00:32:32.025533'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:49:11.720753'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:49:15.904853'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:49:22.216433'},
#  {'user_id': 72, 'created_at': '2025-06-04 00:49:28.506773'},
#  {'user_id': 33, 'created_at': '2025-06-04 00:53:46.157093'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:53:53.766833'},
#  {'user_id': 33, 'created_at': '2025-06-04 00:53:58.054373'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:54:03.513833'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:54:09.988493'},
#  {'user_id': 58, 'created_at': '2025-06-04 00:54:13.325273'},
#  {'user_id': 64, 'created_at': '2025-06-04 00:54:19.050893'},
#  {'user_id': 58, 'created_at': '2025-06-04 00:54:23.649593'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:55:21.448493'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:55:26.096873'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:55:32.601173'},
#  {'user_id': 17, 'created_at': '2025-06-04 00:55:38.059253'},
#  {'user_id': 53, 'created_at': '2025-06-04 00:58:07.388393'},
#  {'user_id': 53, 'created_at': '2025-06-04 00:58:13.578473'},
#  {'user_id': 53, 'created_at': '2025-06-04 00:58:22.089713'},
#  {'user_id': 51, 'created_at': '2025-06-04 00:59:48.140933'},
#  {'user_id': 51, 'created_at': '2025-06-04 00:59:52.174073'},
#  {'user_id': 51, 'created_at': '2025-06-04 00:59:58.583513'},
#  {'user_id': 51, 'created_at': '2025-06-04 01:00:04.224233'},
#  {'user_id': 16, 'created_at': '2025-06-04 01:03:44.839853'},
#  {'user_id': 16, 'created_at': '2025-06-04 01:03:49.686653'},
#  {'user_id': 16, 'created_at': '2025-06-04 01:03:57.132113'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:00.121613'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:04.089053'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:10.553453'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:16.960013'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:24.690473'},
#  {'user_id': 41, 'created_at': '2025-06-04 01:09:30.290873'},
#  {'user_id': 79, 'created_at': '2025-06-04 01:11:36.727673'},
#  {'user_id': 79, 'created_at': '2025-06-04 01:11:45.546113'},
#  {'user_id': 66, 'created_at': '2025-06-04 01:11:52.838093'},
#  {'user_id': 40, 'created_at': '2025-06-04 01:11:55.056773'},
#  {'user_id': 46, 'created_at': '2025-06-04 01:11:59.068913'},
#  {'user_id': 36, 'created_at': '2025-06-04 01:12:02.761973'},
#  {'user_id': 8, 'created_at': '2025-06-04 01:12:06.947573'},
#  {'user_id': 60, 'created_at': '2025-06-04 01:12:09.399653'},
#  {'user_id': 25, 'created_at': '2025-06-04 01:12:11.849453'},
#  {'user_id': 2, 'created_at': '2025-06-04 01:12:14.394353'},
#  {'user_id': 79, 'created_at': '2025-06-04 01:12:18.353333'},
#  {'user_id': 9, 'created_at': '2025-06-04 01:12:20.775053'},
#  {'user_id': 8, 'created_at': '2025-06-04 01:35:26.054153'},
#  {'user_id': 8, 'created_at': '2025-06-04 01:35:31.901693'},
#  {'user_id': 8, 'created_at': '2025-06-04 01:35:38.248433'},
#  {'user_id': 8, 'created_at': '2025-06-04 01:35:44.278013'},
#  {'user_id': 66, 'created_at': '2025-06-04 01:48:58.112753'},
#  {'user_id': 66, 'created_at': '2025-06-04 01:49:04.736933'},
#  {'user_id': 79, 'created_at': '2025-06-04 01:50:27.959633'},
#  {'user_id': 2, 'created_at': '2025-06-04 01:54:23.654993'},
#  {'user_id': 2, 'created_at': '2025-06-04 01:54:28.183553'},
#  {'user_id': 2, 'created_at': '2025-06-04 01:54:34.540553'},
#  {'user_id': 40, 'created_at': '2025-06-04 01:58:27.029513'},
#  {'user_id': 40, 'created_at': '2025-06-04 01:58:33.987293'},
#  {'user_id': 36, 'created_at': '2025-06-04 02:13:34.025993'},
#  {'user_id': 36, 'created_at': '2025-06-04 02:13:38.402333'},
#  {'user_id': 36, 'created_at': '2025-06-04 02:13:45.492653'},
#  {'user_id': 25, 'created_at': '2025-06-04 02:13:55.788953'},
#  {'user_id': 25, 'created_at': '2025-06-04 02:14:03.046493'},
#  {'user_id': 25, 'created_at': '2025-06-04 02:14:09.070793'},
#  {'user_id': 25, 'created_at': '2025-06-04 02:14:16.125893'},
#  {'user_id': 60, 'created_at': '2025-06-04 02:17:55.158533'},
#  {'user_id': 9, 'created_at': '2025-06-04 02:20:47.411153'},
#  {'user_id': 46, 'created_at': '2025-06-04 02:33:35.351153'},
#  {'user_id': 46, 'created_at': '2025-06-04 02:33:41.622173'},
#  {'user_id': 46, 'created_at': '2025-06-04 02:33:47.575193'},
#  {'user_id': 43, 'created_at': '2025-06-04 02:33:55.697453'},
#  {'user_id': 38, 'created_at': '2025-06-04 02:33:58.483133'},
#  {'user_id': 23, 'created_at': '2025-06-04 02:34:02.582873'},
#  {'user_id': 9, 'created_at': '2025-06-04 02:34:06.522293'},
#  {'user_id': 55, 'created_at': '2025-06-04 02:34:11.380673'},
#  {'user_id': 41, 'created_at': '2025-06-04 02:34:15.984353'},
#  {'user_id': 54, 'created_at': '2025-06-04 02:34:19.632353'},
#  {'user_id': 50, 'created_at': '2025-06-04 02:34:23.304113'},
#  {'user_id': 77, 'created_at': '2025-06-04 02:34:27.207293'},
#  {'user_id': 66, 'created_at': '2025-06-04 02:34:30.107333'},
#  {'user_id': 41, 'created_at': '2025-06-04 02:55:44.398373'},
#  {'user_id': 41, 'created_at': '2025-06-04 02:55:51.592973'},
#  {'user_id': 41, 'created_at': '2025-06-04 02:55:57.930113'},
#  {'user_id': 9, 'created_at': '2025-06-04 02:56:02.800853'},
#  {'user_id': 23, 'created_at': '2025-06-04 02:58:08.679353'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:17:53.804273'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:00.326993'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:06.172613'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:14.261273'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:18.794573'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:24.655553'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:31.253753'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:37.213253'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:42.881453'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:48.660773'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:18:55.044473'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:19:01.783853'},
#  {'user_id': 50, 'created_at': '2025-06-04 03:19:06.763253'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:19:10.986593'},
#  {'user_id': 50, 'created_at': '2025-06-04 03:19:16.204613'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:19:20.616293'},
#  {'user_id': 50, 'created_at': '2025-06-04 03:19:24.157133'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:19:28.092293'},
#  {'user_id': 50, 'created_at': '2025-06-04 03:19:32.654693'},
#  {'user_id': 77, 'created_at': '2025-06-04 03:19:37.290953'},
#  {'user_id': 50, 'created_at': '2025-06-04 03:19:42.478553'},
#  {'user_id': 38, 'created_at': '2025-06-04 03:24:33.310313'},
#  {'user_id': 38, 'created_at': '2025-06-04 03:24:37.559393'},
#  {'user_id': 38, 'created_at': '2025-06-04 03:24:43.819613'},
#  {'user_id': 38, 'created_at': '2025-06-04 03:24:52.119413'},
#  {'user_id': 38, 'created_at': '2025-06-04 03:24:57.396773'},
#  {'user_id': 43, 'created_at': '2025-06-04 03:39:27.892193'},
#  {'user_id': 43, 'created_at': '2025-06-04 03:39:32.290313'},
#  {'user_id': 54, 'created_at': '2025-06-04 03:42:11.473553'},
#  {'user_id': 54, 'created_at': '2025-06-04 03:42:15.962693'},
#  {'user_id': 54, 'created_at': '2025-06-04 03:42:23.033873'},
#  {'user_id': 55, 'created_at': '2025-06-04 03:56:45.530753'},
#  {'user_id': 55, 'created_at': '2025-06-04 03:56:51.175013'},
#  {'user_id': 55, 'created_at': '2025-06-04 03:56:56.409293'},
#  {'user_id': 55, 'created_at': '2025-06-04 03:57:01.613933'},
#  {'user_id': 66, 'created_at': '2025-06-04 04:04:23.779793'},
#  {'user_id': 54, 'created_at': '2025-06-04 04:04:33.180353'},
#  {'user_id': 68, 'created_at': '2025-06-04 04:04:37.829813'},
#  {'user_id': 50, 'created_at': '2025-06-04 04:04:40.750193'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:04:43.946093'},
#  {'user_id': 24, 'created_at': '2025-06-04 04:04:47.625293'},
#  {'user_id': 70, 'created_at': '2025-06-04 04:04:53.776493'},
#  {'user_id': 69, 'created_at': '2025-06-04 04:04:57.871913'},
#  {'user_id': 78, 'created_at': '2025-06-04 04:05:00.651413'},
#  {'user_id': 15, 'created_at': '2025-06-04 04:05:03.790853'},
#  {'user_id': 12, 'created_at': '2025-06-04 04:05:08.105633'},
#  {'user_id': 54, 'created_at': '2025-06-04 04:40:53.318033'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:45:58.760513'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:46:03.234173'},
#  {'user_id': 12, 'created_at': '2025-06-04 04:46:08.829533'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:46:12.302573'},
#  {'user_id': 12, 'created_at': '2025-06-04 04:46:18.130913'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:46:24.383513'},
#  {'user_id': 37, 'created_at': '2025-06-04 04:46:29.678093'},
#  {'user_id': 78, 'created_at': '2025-06-04 04:50:57.863153'},
#  {'user_id': 78, 'created_at': '2025-06-04 04:51:02.565713'},
#  {'user_id': 50, 'created_at': '2025-06-04 04:51:08.162513'},
#  {'user_id': 78, 'created_at': '2025-06-04 04:51:13.053593'},
#  {'user_id': 68, 'created_at': '2025-06-04 04:58:12.722033'},
#  {'user_id': 24, 'created_at': '2025-06-04 05:05:21.754433'},
#  {'user_id': 24, 'created_at': '2025-06-04 05:05:30.234653'},
#  {'user_id': 15, 'created_at': '2025-06-04 05:06:18.758033'},
#  {'user_id': 15, 'created_at': '2025-06-04 05:06:23.012933'},
#  {'user_id': 15, 'created_at': '2025-06-04 05:06:36.404633'},
#  {'user_id': 15, 'created_at': '2025-06-04 05:06:41.183453'},
#  {'user_id': 70, 'created_at': '2025-06-04 05:16:04.509713'},
#  {'user_id': 70, 'created_at': '2025-06-04 05:16:09.114473'},
#  {'user_id': 70, 'created_at': '2025-06-04 05:16:16.170833'},
#  {'user_id': 70, 'created_at': '2025-06-04 05:16:22.570313'},
#  {'user_id': 26, 'created_at': '2025-06-04 05:16:30.811373'},
#  {'user_id': 27, 'created_at': '2025-06-04 05:16:34.143053'},
#  {'user_id': 36, 'created_at': '2025-06-04 05:16:37.671713'},
#  {'user_id': 38, 'created_at': '2025-06-04 05:16:41.447033'},
#  {'user_id': 7, 'created_at': '2025-06-04 05:16:46.389533'},
#  {'user_id': 67, 'created_at': '2025-06-04 05:16:51.628613'},
#  {'user_id': 54, 'created_at': '2025-06-04 05:16:56.654093'},
#  {'user_id': 46, 'created_at': '2025-06-04 05:17:01.380893'},
#  {'user_id': 73, 'created_at': '2025-06-04 05:17:05.152793'},
#  {'user_id': 1, 'created_at': '2025-06-04 05:17:08.837033'},
#  {'user_id': 54, 'created_at': '2025-06-04 05:37:58.156013'},
#  {'user_id': 54, 'created_at': '2025-06-04 05:38:07.591613'},
#  {'user_id': 38, 'created_at': '2025-06-04 05:50:21.451253'},
#  {'user_id': 38, 'created_at': '2025-06-04 05:50:29.235773'},
#  {'user_id': 38, 'created_at': '2025-06-04 05:50:32.926193'},
#  {'user_id': 38, 'created_at': '2025-06-04 05:50:39.728993'},
#  {'user_id': 73, 'created_at': '2025-06-04 06:05:48.864953'},
#  {'user_id': 73, 'created_at': '2025-06-04 06:05:54.001853'},
#  {'user_id': 73, 'created_at': '2025-06-04 06:06:00.816593'},
#  {'user_id': 73, 'created_at': '2025-06-04 06:06:04.852673'},
#  {'user_id': 26, 'created_at': '2025-06-04 06:07:42.373973'},
#  {'user_id': 26, 'created_at': '2025-06-04 06:07:48.370913'},
#  {'user_id': 26, 'created_at': '2025-06-04 06:07:53.225153'},
#  {'user_id': 26, 'created_at': '2025-06-04 06:07:59.211893'},
#  {'user_id': 27, 'created_at': '2025-06-04 06:08:08.074253'},
#  {'user_id': 27, 'created_at': '2025-06-04 06:08:11.842073'},
#  {'user_id': 27, 'created_at': '2025-06-04 06:08:19.394393'},
#  {'user_id': 27, 'created_at': '2025-06-04 06:08:25.807553'},
#  {'user_id': 67, 'created_at': '2025-06-04 06:14:19.195013'},
#  {'user_id': 67, 'created_at': '2025-06-04 06:14:25.463813'},
#  {'user_id': 67, 'created_at': '2025-06-04 06:14:31.218293'},
#  {'user_id': 67, 'created_at': '2025-06-04 06:14:38.788493'},
#  {'user_id': 7, 'created_at': '2025-06-04 06:42:16.215053'},
#  {'user_id': 35, 'created_at': '2025-06-04 06:42:26.338493'},
#  {'user_id': 22, 'created_at': '2025-06-04 06:42:30.447773'},
#  {'user_id': 1, 'created_at': '2025-06-04 06:42:34.087313'},
#  {'user_id': 62, 'created_at': '2025-06-04 06:42:38.645273'},
#  {'user_id': 18, 'created_at': '2025-06-04 06:42:43.685573'},
#  {'user_id': 78, 'created_at': '2025-06-04 06:42:48.521153'},
#  {'user_id': 2, 'created_at': '2025-06-04 06:42:53.244653'},
#  {'user_id': 10, 'created_at': '2025-06-04 06:42:58.725293'},
#  {'user_id': 19, 'created_at': '2025-06-04 06:43:05.207093'},
#  {'user_id': 28, 'created_at': '2025-06-04 06:43:09.446693'},
#  {'user_id': 28, 'created_at': '2025-06-04 07:30:34.159733'},
#  {'user_id': 28, 'created_at': '2025-06-04 07:30:42.115253'},
#  {'user_id': 28, 'created_at': '2025-06-04 07:30:51.914633'},
#  {'user_id': 28, 'created_at': '2025-06-04 07:30:56.993273'},
#  {'user_id': 2, 'created_at': '2025-06-04 07:34:46.157333'},
#  {'user_id': 22, 'created_at': '2025-06-04 07:43:28.684673'},
#  {'user_id': 22, 'created_at': '2025-06-04 07:43:34.734833'},
#  {'user_id': 10, 'created_at': '2025-06-04 07:47:08.890913'},
#  {'user_id': 10, 'created_at': '2025-06-04 07:47:13.118993'},
#  {'user_id': 10, 'created_at': '2025-06-04 07:47:19.274933'},
#  {'user_id': 1, 'created_at': '2025-06-04 07:50:17.220593'},
#  {'user_id': 1, 'created_at': '2025-06-04 07:50:24.518033'},
#  {'user_id': 78, 'created_at': '2025-06-04 07:56:11.578433'},
#  {'user_id': 78, 'created_at': '2025-06-04 07:56:16.314893'},
#  {'user_id': 35, 'created_at': '2025-06-04 08:01:37.361993'},
#  {'user_id': 35, 'created_at': '2025-06-04 08:01:44.695073'},
#  {'user_id': 35, 'created_at': '2025-06-04 08:01:53.644133'},
#  {'user_id': 18, 'created_at': '2025-06-04 08:07:55.240433'},
#  {'user_id': 18, 'created_at': '2025-06-04 08:07:59.290193'},
#  {'user_id': 18, 'created_at': '2025-06-04 08:08:08.575013'},
#  {'user_id': 18, 'created_at': '2025-06-04 08:08:13.088033'},
#  {'user_id': 62, 'created_at': '2025-06-04 08:10:29.320073'},
#  {'user_id': 62, 'created_at': '2025-06-04 08:10:33.717473'},
#  {'user_id': 62, 'created_at': '2025-06-04 08:10:40.796453'},
#  {'user_id': 62, 'created_at': '2025-06-04 08:10:47.551133'},
#  {'user_id': 19, 'created_at': '2025-06-04 08:11:21.032993'},
#  {'user_id': 19, 'created_at': '2025-06-04 08:11:27.341873'},
#  {'user_id': 19, 'created_at': '2025-06-04 08:11:34.577693'},
#  {'user_id': 8, 'created_at': '2025-06-04 08:11:41.293253'},
#  {'user_id': 57, 'created_at': '2025-06-04 08:11:44.789273'},
#  {'user_id': 14, 'created_at': '2025-06-04 08:11:48.725753'},
#  {'user_id': 39, 'created_at': '2025-06-04 08:11:52.742033'},
#  {'user_id': 44, 'created_at': '2025-06-04 08:11:57.843053'},
#  {'user_id': 50, 'created_at': '2025-06-04 08:12:01.514333'},
#  {'user_id': 7, 'created_at': '2025-06-04 08:12:08.644733'},
#  {'user_id': 23, 'created_at': '2025-06-04 08:12:15.563813'},
#  {'user_id': 15, 'created_at': '2025-06-04 08:12:19.372433'},
#  {'user_id': 53, 'created_at': '2025-06-04 08:12:24.106133'},
#  {'user_id': 14, 'created_at': '2025-06-04 08:41:31.128353'},
#  {'user_id': 23, 'created_at': '2025-06-04 08:45:54.554393'},
#  {'user_id': 44, 'created_at': '2025-06-04 09:04:17.940953'},
#  {'user_id': 44, 'created_at': '2025-06-04 09:04:22.112153'},
#  {'user_id': 50, 'created_at': '2025-06-04 09:06:31.909433'},
#  {'user_id': 57, 'created_at': '2025-06-04 09:16:12.234053'},
#  {'user_id': 57, 'created_at': '2025-06-04 09:16:17.866673'},
#  {'user_id': 15, 'created_at': '2025-06-04 09:17:51.601313'},
#  {'user_id': 8, 'created_at': '2025-06-04 09:25:02.175353'},
#  {'user_id': 8, 'created_at': '2025-06-04 09:25:06.920933'},
#  {'user_id': 53, 'created_at': '2025-06-04 09:29:35.288633'},
#  {'user_id': 53, 'created_at': '2025-06-04 09:29:40.187153'},
#  {'user_id': 7, 'created_at': '2025-06-04 09:32:23.380253'},
#  {'user_id': 39, 'created_at': '2025-06-04 09:32:36.734453'},
#  {'user_id': 31, 'created_at': '2025-06-04 09:32:46.632773'},
#  {'user_id': 22, 'created_at': '2025-06-04 09:32:52.191833'},
#  {'user_id': 43, 'created_at': '2025-06-04 09:33:01.440293'},
#  {'user_id': 64, 'created_at': '2025-06-04 09:33:08.721653'},
#  {'user_id': 60, 'created_at': '2025-06-04 09:33:13.186133'},
#  {'user_id': 71, 'created_at': '2025-06-04 09:33:18.648713'},
#  {'user_id': 32, 'created_at': '2025-06-04 09:33:24.085373'},
#  {'user_id': 14, 'created_at': '2025-06-04 09:33:30.451913'},
#  {'user_id': 25, 'created_at': '2025-06-04 09:33:36.044573'},
#  {'user_id': 45, 'created_at': '2025-06-04 09:33:41.287373'},
#  {'user_id': 71, 'created_at': '2025-06-04 10:52:47.725433'},
#  {'user_id': 22, 'created_at': '2025-06-04 10:57:55.450913'},
#  {'user_id': 43, 'created_at': '2025-06-04 11:02:27.987293'},
#  {'user_id': 25, 'created_at': '2025-06-04 11:07:22.013873'},
#  {'user_id': 31, 'created_at': '2025-06-04 11:09:28.608713'},
#  {'user_id': 31, 'created_at': '2025-06-04 11:09:33.201773'},
#  {'user_id': 60, 'created_at': '2025-06-04 11:17:12.401933'},
#  {'user_id': 14, 'created_at': '2025-06-04 11:24:15.131393'},
#  {'user_id': 45, 'created_at': '2025-06-04 11:26:27.876713'},
#  {'user_id': 45, 'created_at': '2025-06-04 11:26:31.810793'},
#  {'user_id': 45, 'created_at': '2025-06-04 11:26:37.662353'},
#  {'user_id': 64, 'created_at': '2025-06-04 11:41:55.644833'},
#  {'user_id': 32, 'created_at': '2025-06-04 11:56:58.126913'},
#  {'user_id': 32, 'created_at': '2025-06-04 11:57:05.926973'},
#  {'user_id': 70, 'created_at': '2025-06-04 11:57:14.427473'},
#  {'user_id': 48, 'created_at': '2025-06-04 11:57:18.746513'},
#  {'user_id': 35, 'created_at': '2025-06-04 11:57:23.789693'},
#  {'user_id': 77, 'created_at': '2025-06-04 11:57:28.999553'},
#  {'user_id': 38, 'created_at': '2025-06-04 11:57:33.855653'},
#  {'user_id': 0, 'created_at': '2025-06-04 11:57:41.030213'},
#  {'user_id': 2, 'created_at': '2025-06-04 11:57:47.550293'},
#  {'user_id': 16, 'created_at': '2025-06-04 11:57:53.281133'},
#  {'user_id': 9, 'created_at': '2025-06-04 11:58:00.881693'},
#  {'user_id': 64, 'created_at': '2025-06-04 11:58:07.818293'},
#  {'user_id': 77, 'created_at': '2025-06-04 12:24:29.829233'},
#  {'user_id': 38, 'created_at': '2025-06-04 12:29:37.346573'},
#  {'user_id': 2, 'created_at': '2025-06-04 12:49:29.428493'},
#  {'user_id': 35, 'created_at': '2025-06-04 13:06:39.660593'},
#  {'user_id': 9, 'created_at': '2025-06-04 13:09:10.721933'},
#  {'user_id': 48, 'created_at': '2025-06-04 13:15:40.843313'},
#  {'user_id': 48, 'created_at': '2025-06-04 13:15:48.825953'},
#  {'user_id': 48, 'created_at': '2025-06-04 13:15:54.536813'},
#  {'user_id': 64, 'created_at': '2025-06-04 13:18:50.261333'},
#  {'user_id': 16, 'created_at': '2025-06-04 13:26:30.374693'},
#  {'user_id': 70, 'created_at': '2025-06-04 13:28:05.832893'},
#  {'user_id': 0, 'created_at': '2025-06-04 13:35:34.463933'},
#  {'user_id': 28, 'created_at': '2025-06-04 13:35:47.299793'},
#  {'user_id': 37, 'created_at': '2025-06-04 13:35:53.841233'},
#  {'user_id': 74, 'created_at': '2025-06-04 13:35:58.309433'},
#  {'user_id': 63, 'created_at': '2025-06-04 13:36:03.508613'},
#  {'user_id': 57, 'created_at': '2025-06-04 13:36:09.494513'},
#  {'user_id': 45, 'created_at': '2025-06-04 13:36:14.738153'},
#  {'user_id': 18, 'created_at': '2025-06-04 13:36:19.219313'},
#  {'user_id': 52, 'created_at': '2025-06-04 13:36:23.772113'},
#  {'user_id': 10, 'created_at': '2025-06-04 13:36:28.663073'},
#  {'user_id': 70, 'created_at': '2025-06-04 13:36:40.654313'},
#  {'user_id': 45, 'created_at': '2025-06-04 14:22:15.915053'},
#  {'user_id': 37, 'created_at': '2025-06-04 14:25:44.575493'},
#  {'user_id': 37, 'created_at': '2025-06-04 14:25:49.294133'},
#  {'user_id': 37, 'created_at': '2025-06-04 14:25:54.034373'},
#  {'user_id': 57, 'created_at': '2025-06-04 14:52:37.974533'},
#  {'user_id': 18, 'created_at': '2025-06-04 15:17:30.298193'},
#  {'user_id': 74, 'created_at': '2025-06-04 15:32:00.444233'},
#  {'user_id': 10, 'created_at': '2025-06-04 15:36:33.543053'},
#  {'user_id': 52, 'created_at': '2025-06-04 15:44:04.716953'},
#  {'user_id': 52, 'created_at': '2025-06-04 15:44:08.896013'},
#  {'user_id': 52, 'created_at': '2025-06-04 15:44:16.557173'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:49:38.738033'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:49:44.829953'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:49:52.672973'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:50:04.725413'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:50:28.359533'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:50:33.338933'},
#  {'user_id': 63, 'created_at': '2025-06-04 15:50:40.199993'},
#  {'user_id': 28, 'created_at': '2025-06-04 16:01:50.367473'},
#  {'user_id': 70, 'created_at': '2025-06-04 16:07:39.547253'},
#  {'user_id': 38, 'created_at': '2025-06-04 16:07:52.804133'},
#  {'user_id': 28, 'created_at': '2025-06-04 16:07:57.978833'},
#  {'user_id': 52, 'created_at': '2025-06-04 16:08:05.151353'},
#  {'user_id': 47, 'created_at': '2025-06-04 16:08:12.256193'},
#  {'user_id': 40, 'created_at': '2025-06-04 16:08:17.387813'},
#  {'user_id': 3, 'created_at': '2025-06-04 16:08:22.581293'},
#  {'user_id': 61, 'created_at': '2025-06-04 16:08:28.044233'},
#  {'user_id': 74, 'created_at': '2025-06-04 16:08:34.970153'},
#  {'user_id': 77, 'created_at': '2025-06-04 16:08:39.271853'},
#  {'user_id': 23, 'created_at': '2025-06-04 16:08:45.374933'},
#  {'user_id': 38, 'created_at': '2025-06-04 16:38:02.766653'},
#  {'user_id': 52, 'created_at': '2025-06-04 17:05:27.952373'},
#  {'user_id': 40, 'created_at': '2025-06-04 17:14:54.653633'},
#  {'user_id': 28, 'created_at': '2025-06-04 17:17:47.147453'},
#  {'user_id': 77, 'created_at': '2025-06-04 17:42:15.198533'},
#  {'user_id': 77, 'created_at': '2025-06-04 17:42:20.471033'},
#  {'user_id': 77, 'created_at': '2025-06-04 17:42:26.379413'},
#  {'user_id': 77, 'created_at': '2025-06-04 17:42:31.182893'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:20.216093'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:24.241253'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:31.540673'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:44.045393'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:54.211913'},
#  {'user_id': 47, 'created_at': '2025-06-04 17:53:57.969173'},
#  {'user_id': 3, 'created_at': '2025-06-04 18:01:21.191633'},
#  {'user_id': 3, 'created_at': '2025-06-04 18:01:25.558853'},
#  {'user_id': 23, 'created_at': '2025-06-04 18:01:57.745433'},
#  {'user_id': 74, 'created_at': '2025-06-04 18:14:40.270973'},
#  {'user_id': 61, 'created_at': '2025-06-04 18:15:58.637453'},
#  {'user_id': 61, 'created_at': '2025-06-04 18:16:05.947553'},
#  {'user_id': 19, 'created_at': '2025-06-04 18:16:15.360713'},
#  {'user_id': 71, 'created_at': '2025-06-04 18:16:24.217313'},
#  {'user_id': 8, 'created_at': '2025-06-04 18:16:30.766973'},
#  {'user_id': 3, 'created_at': '2025-06-04 18:16:38.222273'},
#  {'user_id': 24, 'created_at': '2025-06-04 18:16:47.174453'},
#  {'user_id': 37, 'created_at': '2025-06-04 18:16:53.705933'},
#  {'user_id': 41, 'created_at': '2025-06-04 18:16:59.833373'},
#  {'user_id': 76, 'created_at': '2025-06-04 18:17:05.327093'},
#  {'user_id': 58, 'created_at': '2025-06-04 18:17:10.599113'},
#  {'user_id': 9, 'created_at': '2025-06-04 18:17:15.421073'},
#  {'user_id': 71, 'created_at': '2025-06-04 18:51:53.891873'},
#  {'user_id': 24, 'created_at': '2025-06-04 19:15:01.848473'},
#  {'user_id': 37, 'created_at': '2025-06-04 19:21:54.980453'},
#  {'user_id': 3, 'created_at': '2025-06-04 19:40:50.124413'},
#  {'user_id': 58, 'created_at': '2025-06-04 19:55:03.055793'},
#  {'user_id': 19, 'created_at': '2025-06-04 19:56:16.960073'},
#  {'user_id': 9, 'created_at': '2025-06-04 20:03:08.430833'},
#  {'user_id': 41, 'created_at': '2025-06-04 20:04:06.881153'},
#  {'user_id': 41, 'created_at': '2025-06-04 20:04:13.973813'},
#  {'user_id': 41, 'created_at': '2025-06-04 20:04:24.499013'},
#  {'user_id': 76, 'created_at': '2025-06-04 20:52:17.223353'},
#  {'user_id': 76, 'created_at': '2025-06-04 20:52:24.577313'},
#  {'user_id': 42, 'created_at': '2025-06-04 20:52:37.352033'},
#  {'user_id': 77, 'created_at': '2025-06-04 20:52:43.095653'},
#  {'user_id': 59, 'created_at': '2025-06-04 20:52:47.903333'},
#  {'user_id': 1, 'created_at': '2025-06-04 20:52:56.838473'},
#  {'user_id': 79, 'created_at': '2025-06-04 20:53:04.289633'},
#  {'user_id': 57, 'created_at': '2025-06-04 20:53:10.011173'},
#  {'user_id': 58, 'created_at': '2025-06-04 20:53:14.819393'},
#  {'user_id': 4, 'created_at': '2025-06-04 20:53:20.304833'},
#  {'user_id': 32, 'created_at': '2025-06-04 20:53:25.881413'},
#  {'user_id': 19, 'created_at': '2025-06-04 20:53:31.846013'},
#  {'user_id': 1, 'created_at': '2025-06-04 21:36:59.921993'},
#  {'user_id': 1, 'created_at': '2025-06-04 21:37:05.760593'},
#  {'user_id': 77, 'created_at': '2025-06-04 21:48:35.418053'},
#  {'user_id': 57, 'created_at': '2025-06-04 22:26:03.190073'},
#  {'user_id': 59, 'created_at': '2025-06-04 22:48:29.017073'},
#  {'user_id': 59, 'created_at': '2025-06-04 22:48:35.437193'},
#  {'user_id': 79, 'created_at': '2025-06-04 23:12:37.572893'},
#  {'user_id': 42, 'created_at': '2025-06-04 23:18:09.371873'},
#  {'user_id': 42, 'created_at': '2025-06-04 23:18:13.425233'},
#  {'user_id': 42, 'created_at': '2025-06-04 23:18:21.060593'},
#  {'user_id': 42, 'created_at': '2025-06-04 23:18:26.187173'},
#  {'user_id': 58, 'created_at': '2025-06-04 23:25:24.765233'},
#  {'user_id': 32, 'created_at': '2025-06-05 00:15:07.764173'},
#  {'user_id': 4, 'created_at': '2025-06-05 00:44:32.682473'},
#  {'user_id': 4, 'created_at': '2025-06-05 00:44:39.898793'},
#  {'user_id': 19, 'created_at': '2025-06-05 00:56:31.364693'},
#  {'user_id': 51, 'created_at': '2025-06-05 00:56:42.166673'},
#  {'user_id': 67, 'created_at': '2025-06-05 00:56:49.952693'},
#  {'user_id': 40, 'created_at': '2025-06-05 00:56:56.888993'},
#  {'user_id': 28, 'created_at': '2025-06-05 00:57:03.490853'},
#  {'user_id': 42, 'created_at': '2025-06-05 00:57:11.023193'},
#  {'user_id': 30, 'created_at': '2025-06-05 00:57:16.426433'},
#  {'user_id': 53, 'created_at': '2025-06-05 00:57:22.765973'},
#  {'user_id': 44, 'created_at': '2025-06-05 00:57:28.003073'},
#  {'user_id': 70, 'created_at': '2025-06-05 00:57:32.855453'},
#  {'user_id': 47, 'created_at': '2025-06-05 00:57:39.886433'},
#  {'user_id': 40, 'created_at': '2025-06-05 01:26:55.416413'},
#  {'user_id': 67, 'created_at': '2025-06-05 01:39:04.382693'},
#  {'user_id': 42, 'created_at': '2025-06-05 02:10:25.718033'},
#  {'user_id': 42, 'created_at': '2025-06-05 02:10:30.312473'},
#  {'user_id': 51, 'created_at': '2025-06-05 02:25:42.277913'},
#  {'user_id': 28, 'created_at': '2025-06-05 02:51:01.901213'},
#  {'user_id': 53, 'created_at': '2025-06-05 03:10:56.100713'},
#  {'user_id': 70, 'created_at': '2025-06-05 03:27:55.491473'},
#  {'user_id': 44, 'created_at': '2025-06-05 03:39:18.061313'},
#  {'user_id': 47, 'created_at': '2025-06-05 04:19:57.221333'},
#  {'user_id': 30, 'created_at': '2025-06-05 04:30:28.006733'},
#  {'user_id': 72, 'created_at': '2025-06-05 04:30:38.094173'},
#  {'user_id': 9, 'created_at': '2025-06-05 04:30:43.682933'},
#  {'user_id': 19, 'created_at': '2025-06-05 04:30:50.664713'},
#  {'user_id': 73, 'created_at': '2025-06-05 04:30:57.315473'},
#  {'user_id': 57, 'created_at': '2025-06-05 04:31:02.713373'},
#  {'user_id': 47, 'created_at': '2025-06-05 04:31:09.484793'},
#  {'user_id': 33, 'created_at': '2025-06-05 04:31:15.035753'},
#  {'user_id': 29, 'created_at': '2025-06-05 04:31:20.499233'},
#  {'user_id': 60, 'created_at': '2025-06-05 04:31:33.659333'},
#  {'user_id': 13, 'created_at': '2025-06-05 04:31:41.274233'},
#  {'user_id': 72, 'created_at': '2025-06-05 05:23:56.304053'},
#  {'user_id': 9, 'created_at': '2025-06-05 05:39:23.778833'},
#  {'user_id': 19, 'created_at': '2025-06-05 05:59:35.124893'},
#  {'user_id': 57, 'created_at': '2025-06-05 06:24:57.335693'},
#  {'user_id': 47, 'created_at': '2025-06-05 07:03:33.089573'},
#  {'user_id': 73, 'created_at': '2025-06-05 07:18:00.846833'},
#  {'user_id': 13, 'created_at': '2025-06-05 07:30:50.322293'},
#  {'user_id': 13, 'created_at': '2025-06-05 07:30:54.763013'},
#  {'user_id': 60, 'created_at': '2025-06-05 07:59:27.666053'},
#  {'user_id': 33, 'created_at': '2025-06-05 08:24:39.020333'},
#  {'user_id': 29, 'created_at': '2025-06-05 08:25:00.149633'},
#  {'user_id': 29, 'created_at': '2025-06-05 08:25:05.065313'},
#  {'user_id': 29, 'created_at': '2025-06-05 08:25:12.247313'},
#  {'user_id': 73, 'created_at': '2025-06-05 08:25:22.394393'},
#  {'user_id': 70, 'created_at': '2025-06-05 08:25:28.994753'},
#  {'user_id': 13, 'created_at': '2025-06-05 08:25:36.710393'},
#  {'user_id': 12, 'created_at': '2025-06-05 08:25:44.520233'},
#  {'user_id': 50, 'created_at': '2025-06-05 08:25:51.766673'},
#  {'user_id': 15, 'created_at': '2025-06-05 08:25:59.495633'},
#  {'user_id': 71, 'created_at': '2025-06-05 08:26:07.717193'},
#  {'user_id': 10, 'created_at': '2025-06-05 08:26:17.274773'},
#  {'user_id': 63, 'created_at': '2025-06-05 08:26:23.052413'},
#  {'user_id': 34, 'created_at': '2025-06-05 08:26:28.586933'},
#  {'user_id': 70, 'created_at': '2025-06-05 09:02:38.716613'},
#  {'user_id': 73, 'created_at': '2025-06-05 09:20:06.934013'},
#  {'user_id': 50, 'created_at': '2025-06-05 09:34:59.835473'},
#  {'user_id': 13, 'created_at': '2025-06-05 10:00:28.462133'},
#  {'user_id': 15, 'created_at': '2025-06-05 10:11:05.208173'},
#  {'user_id': 12, 'created_at': '2025-06-05 10:35:55.557833'},
#  {'user_id': 10, 'created_at': '2025-06-05 10:41:38.897333'},
#  {'user_id': 34, 'created_at': '2025-06-05 11:08:29.228153'},
#  {'user_id': 34, 'created_at': '2025-06-05 11:08:32.853473'},
#  {'user_id': 63, 'created_at': '2025-06-05 11:18:38.688293'},
#  {'user_id': 63, 'created_at': '2025-06-05 11:18:44.770253'},
#  {'user_id': 77, 'created_at': '2025-06-05 11:19:00.337433'},
#  {'user_id': 52, 'created_at': '2025-06-05 11:19:08.977013'},
#  {'user_id': 36, 'created_at': '2025-06-05 11:19:16.302353'},
#  {'user_id': 78, 'created_at': '2025-06-05 11:19:24.513173'},
#  {'user_id': 66, 'created_at': '2025-06-05 11:19:34.228733'},
#  {'user_id': 65, 'created_at': '2025-06-05 11:19:42.095693'},
#  {'user_id': 50, 'created_at': '2025-06-05 11:19:49.220993'},
#  {'user_id': 64, 'created_at': '2025-06-05 11:19:58.352873'},
#  {'user_id': 76, 'created_at': '2025-06-05 11:20:06.022733'},
#  {'user_id': 34, 'created_at': '2025-06-05 11:20:13.957673'},
#  {'user_id': 77, 'created_at': '2025-06-05 11:52:33.599513'},
#  {'user_id': 52, 'created_at': '2025-06-05 12:08:38.745233'},
#  {'user_id': 36, 'created_at': '2025-06-05 12:31:20.546093'},
#  {'user_id': 66, 'created_at': '2025-06-05 12:45:17.744513'},
#  {'user_id': 78, 'created_at': '2025-06-05 12:48:33.954593'},
#  {'user_id': 50, 'created_at': '2025-06-05 13:05:09.948173'},
#  {'user_id': 65, 'created_at': '2025-06-05 13:19:48.488093'},
#  {'user_id': 64, 'created_at': '2025-06-05 13:35:39.607373'},
#  {'user_id': 34, 'created_at': '2025-06-05 13:46:46.714313'},
#  {'user_id': 76, 'created_at': '2025-06-05 13:51:07.399373'},
#  {'user_id': 62, 'created_at': '2025-06-05 13:51:16.553393'},
#  {'user_id': 61, 'created_at': '2025-06-05 13:51:25.779653'},
#  {'user_id': 9, 'created_at': '2025-06-05 13:51:35.150453'},
#  {'user_id': 73, 'created_at': '2025-06-05 13:51:46.414973'},
#  {'user_id': 60, 'created_at': '2025-06-05 13:51:53.867453'},
#  {'user_id': 13, 'created_at': '2025-06-05 13:52:00.135833'},
#  {'user_id': 41, 'created_at': '2025-06-05 13:52:06.811613'},
#  {'user_id': 63, 'created_at': '2025-06-05 13:52:14.560493'},
#  {'user_id': 67, 'created_at': '2025-06-05 13:52:20.819453'},
#  {'user_id': 27, 'created_at': '2025-06-05 13:52:26.880773'},
#  {'user_id': 9, 'created_at': '2025-06-05 14:26:58.561553'},
#  {'user_id': 61, 'created_at': '2025-06-05 14:52:02.565293'},
#  {'user_id': 73, 'created_at': '2025-06-05 15:05:21.218393'},
#  {'user_id': 41, 'created_at': '2025-06-05 16:01:36.980513'},
#  {'user_id': 13, 'created_at': '2025-06-05 16:14:28.280213'},
#  {'user_id': 13, 'created_at': '2025-06-05 16:14:32.244953'},
#  {'user_id': 63, 'created_at': '2025-06-05 16:28:36.899033'},
#  {'user_id': 27, 'created_at': '2025-06-05 16:52:04.492673'},
#  {'user_id': 62, 'created_at': '2025-06-05 17:14:15.707813'},
#  {'user_id': 67, 'created_at': '2025-06-05 17:36:44.824253'},
#  {'user_id': 47, 'created_at': '2025-06-05 17:36:55.226033'},
#  {'user_id': 66, 'created_at': '2025-06-05 17:37:04.651013'},
#  {'user_id': 57, 'created_at': '2025-06-05 17:37:13.973813'},
#  {'user_id': 43, 'created_at': '2025-06-05 17:37:24.264893'},
#  {'user_id': 1, 'created_at': '2025-06-05 17:37:33.042353'},
#  {'user_id': 49, 'created_at': '2025-06-05 17:37:41.182733'},
#  {'user_id': 17, 'created_at': '2025-06-05 17:37:49.406873'},
#  {'user_id': 61, 'created_at': '2025-06-05 17:37:58.142753'},
#  {'user_id': 6, 'created_at': '2025-06-05 17:38:06.797393'},
#  {'user_id': 71, 'created_at': '2025-06-05 17:38:13.179833'},
#  {'user_id': 47, 'created_at': '2025-06-05 18:17:13.704053'},
#  {'user_id': 66, 'created_at': '2025-06-05 18:56:51.376733'},
#  {'user_id': 43, 'created_at': '2025-06-05 19:22:54.162113'},
#  {'user_id': 57, 'created_at': '2025-06-05 19:35:56.445113'},
#  {'user_id': 1, 'created_at': '2025-06-05 20:08:30.859073'},
#  {'user_id': 1, 'created_at': '2025-06-05 20:08:37.961513'},
#  {'user_id': 1, 'created_at': '2025-06-05 20:08:45.494993'},
#  {'user_id': 49, 'created_at': '2025-06-05 20:34:14.925113'},
#  {'user_id': 49, 'created_at': '2025-06-05 20:34:20.351693'},
#  {'user_id': 61, 'created_at': '2025-06-05 20:39:06.903893'},
#  {'user_id': 71, 'created_at': '2025-06-05 21:12:39.201713'},
#  {'user_id': 17, 'created_at': '2025-06-05 21:24:00.769193'},
#  {'user_id': 6, 'created_at': '2025-06-05 21:51:39.711653'},
#  {'user_id': 6, 'created_at': '2025-06-05 21:51:46.999193'},
#  {'user_id': 27, 'created_at': '2025-06-05 21:51:56.636033'},
#  {'user_id': 2, 'created_at': '2025-06-05 21:52:06.447233'},
#  {'user_id': 67, 'created_at': '2025-06-05 21:52:14.986433'},
#  {'user_id': 70, 'created_at': '2025-06-05 21:52:24.713993'},
#  {'user_id': 32, 'created_at': '2025-06-05 21:52:34.224173'},
#  {'user_id': 12, 'created_at': '2025-06-05 21:52:43.620173'},
#  {'user_id': 75, 'created_at': '2025-06-05 21:52:52.928153'},
#  {'user_id': 51, 'created_at': '2025-06-05 21:53:03.150953'},
#  {'user_id': 78, 'created_at': '2025-06-05 21:53:11.924033'},
#  {'user_id': 33, 'created_at': '2025-06-05 21:53:20.386013'},
#  {'user_id': 27, 'created_at': '2025-06-05 22:39:36.701573'},
#  {'user_id': 2, 'created_at': '2025-06-05 22:41:22.048553'},
#  {'user_id': 67, 'created_at': '2025-06-05 23:26:46.539833'},
#  {'user_id': 32, 'created_at': '2025-06-05 23:44:24.870233'},
#  {'user_id': 12, 'created_at': '2025-06-06 00:04:56.032073'},
#  {'user_id': 51, 'created_at': '2025-06-06 00:22:49.259693'},
#  {'user_id': 51, 'created_at': '2025-06-06 00:22:53.149793'},
#  {'user_id': 75, 'created_at': '2025-06-06 00:33:45.606713'},
#  {'user_id': 75, 'created_at': '2025-06-06 00:33:52.723073'},
#  {'user_id': 75, 'created_at': '2025-06-06 00:33:58.284173'},
#  {'user_id': 75, 'created_at': '2025-06-06 00:34:03.427973'},
#  {'user_id': 78, 'created_at': '2025-06-06 00:42:14.004713'},
#  {'user_id': 33, 'created_at': '2025-06-06 01:09:12.313133'},
#  {'user_id': 47, 'created_at': '2025-06-06 01:09:23.158553'},
#  {'user_id': 14, 'created_at': '2025-06-06 01:09:32.731733'},
#  {'user_id': 50, 'created_at': '2025-06-06 01:09:42.544193'},
#  {'user_id': 49, 'created_at': '2025-06-06 01:09:52.909253'},
#  {'user_id': 23, 'created_at': '2025-06-06 01:10:03.819113'},
#  {'user_id': 56, 'created_at': '2025-06-06 01:10:13.819673'},
#  {'user_id': 64, 'created_at': '2025-06-06 01:10:24.206093'},
#  {'user_id': 60, 'created_at': '2025-06-06 01:10:35.002193'},
#  {'user_id': 69, 'created_at': '2025-06-06 01:10:43.199753'},
#  {'user_id': 66, 'created_at': '2025-06-06 01:10:53.568113'},
#  {'user_id': 14, 'created_at': '2025-06-06 01:40:11.107253'},
#  {'user_id': 49, 'created_at': '2025-06-06 02:07:24.269513'},
#  {'user_id': 50, 'created_at': '2025-06-06 02:32:35.711933'},
#  {'user_id': 56, 'created_at': '2025-06-06 03:12:01.784213'},
#  {'user_id': 23, 'created_at': '2025-06-06 03:22:02.313053'},
#  {'user_id': 64, 'created_at': '2025-06-06 03:41:50.983853'},
#  {'user_id': 60, 'created_at': '2025-06-06 04:07:55.734293'},
#  {'user_id': 66, 'created_at': '2025-06-06 04:43:31.315733'},
#  {'user_id': 69, 'created_at': '2025-06-06 04:49:16.736633'},
#  {'user_id': 69, 'created_at': '2025-06-06 04:49:20.393153'},
#  {'user_id': 69, 'created_at': '2025-06-06 04:49:30.576533'},
#  {'user_id': 16, 'created_at': '2025-06-06 04:49:39.146993'},
#  {'user_id': 37, 'created_at': '2025-06-06 04:49:51.031433'},
#  {'user_id': 5, 'created_at': '2025-06-06 04:50:00.059153'},
#  {'user_id': 32, 'created_at': '2025-06-06 04:50:08.953133'},
#  {'user_id': 35, 'created_at': '2025-06-06 04:50:19.427273'},
#  {'user_id': 17, 'created_at': '2025-06-06 04:50:28.863113'},
#  {'user_id': 65, 'created_at': '2025-06-06 04:50:41.086193'},
#  {'user_id': 23, 'created_at': '2025-06-06 04:50:50.048393'},
#  {'user_id': 52, 'created_at': '2025-06-06 04:50:59.467313'},
#  {'user_id': 56, 'created_at': '2025-06-06 04:51:08.947073'},
#  {'user_id': 16, 'created_at': '2025-06-06 06:08:22.435193'},
#  {'user_id': 5, 'created_at': '2025-06-06 06:17:31.349453'},
#  {'user_id': 5, 'created_at': '2025-06-06 06:17:37.792253'},
#  {'user_id': 5, 'created_at': '2025-06-06 06:17:47.221853'},
#  {'user_id': 37, 'created_at': '2025-06-06 06:35:52.640273'},
#  {'user_id': 37, 'created_at': '2025-06-06 06:35:56.640953'},
#  {'user_id': 35, 'created_at': '2025-06-06 07:20:58.853093'},
#  {'user_id': 32, 'created_at': '2025-06-06 07:27:40.597313'},
#  {'user_id': 23, 'created_at': '2025-06-06 09:03:38.099153'},
#  {'user_id': 17, 'created_at': '2025-06-06 09:33:49.769693'},
#  {'user_id': 17, 'created_at': '2025-06-06 09:33:54.244313'},
#  {'user_id': 56, 'created_at': '2025-06-06 09:41:32.330573'},
#  {'user_id': 52, 'created_at': '2025-06-06 10:00:30.794273'},
#  {'user_id': 75, 'created_at': '2025-06-06 10:00:41.285033'},
#  {'user_id': 23, 'created_at': '2025-06-06 10:00:48.416393'},
#  {'user_id': 62, 'created_at': '2025-06-06 10:00:55.686833'},
#  {'user_id': 70, 'created_at': '2025-06-06 10:01:01.498913'},
#  {'user_id': 77, 'created_at': '2025-06-06 10:01:08.482733'},
#  {'user_id': 19, 'created_at': '2025-06-06 10:01:14.890673'},
#  {'user_id': 11, 'created_at': '2025-06-06 10:01:21.481733'},
#  {'user_id': 28, 'created_at': '2025-06-06 10:01:28.764893'},
#  {'user_id': 46, 'created_at': '2025-06-06 10:01:35.753513'},
#  {'user_id': 30, 'created_at': '2025-06-06 10:01:45.143153'},
#  {'user_id': 62, 'created_at': '2025-06-06 10:37:12.313253'},
#  {'user_id': 75, 'created_at': '2025-06-06 11:27:08.432933'},
#  {'user_id': 28, 'created_at': '2025-06-06 12:07:32.279753'},
#  {'user_id': 46, 'created_at': '2025-06-06 12:19:58.207433'},
#  {'user_id': 30, 'created_at': '2025-06-06 12:33:44.411633'},
#  {'user_id': 44, 'created_at': '2025-06-06 12:33:54.741593'},
#  {'user_id': 40, 'created_at': '2025-06-06 12:34:04.789793'},
#  {'user_id': 14, 'created_at': '2025-06-06 12:34:14.041913'},
#  {'user_id': 28, 'created_at': '2025-06-06 12:34:20.658353'},
#  {'user_id': 55, 'created_at': '2025-06-06 12:34:30.356633'},
#  {'user_id': 16, 'created_at': '2025-06-06 12:34:39.666353'},
#  {'user_id': 23, 'created_at': '2025-06-06 12:34:49.867373'},
#  {'user_id': 5, 'created_at': '2025-06-06 12:34:58.363493'},
#  {'user_id': 13, 'created_at': '2025-06-06 12:35:07.181753'},
#  {'user_id': 43, 'created_at': '2025-06-06 12:35:15.911753'},
#  {'user_id': 44, 'created_at': '2025-06-06 13:13:02.753093'},
#  {'user_id': 40, 'created_at': '2025-06-06 13:28:07.785653'},
#  {'user_id': 14, 'created_at': '2025-06-06 13:56:09.739733'},
#  {'user_id': 55, 'created_at': '2025-06-06 14:14:23.609693'},
#  {'user_id': 16, 'created_at': '2025-06-06 14:42:08.177633'},
#  {'user_id': 43, 'created_at': '2025-06-06 15:22:28.675913'},
#  {'user_id': 5, 'created_at': '2025-06-06 15:30:52.420793'}]
